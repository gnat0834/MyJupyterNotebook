# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Natalie Young**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I like working figuring out how and why certain trends or outcomes occur. I also like working with numbers and would like to apply my math skills in a more direct way.

# %% [markdown]
# ### My code will organize a list of fruits into alphabetical order.

# %%
fruits = ('kiwi','apple','peach','banana','watermelon','pineapple','orange')
print(sorted(fruits))
# Out:
# ['apple', 'banana', 'kiwi', 'orange', 'peach', 'pineapple', 'watermelon']

# %% [markdown]
# Tomatoes are a ~~vegetable~~ fruit.
#
# 1. Make a table
# 2. Divide food into fruits and vegetables
#
# Vegetable | Fruit
# --- | ---
# Broccoli | Apple
# Carrot | Banana
# Lettuce | Cantelope
# Peas | Orange
